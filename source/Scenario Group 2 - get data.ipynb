# %%
import matplotlib.pyplot as plt
from Objects.Simulation import Simulation
import numpy as np
import pandas as pd
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab
# %matplotlib inline

from matplotlib import lines, markers
from cycler import cycler

# Create cycler object. Use any styling from above you please
monochromeWithMarker = (cycler('color', ['k']) * cycler('linestyle', ['-', '--', ':', '-.']) * cycler('marker', [ '.' ,'^']))
monochromeNoMarker = (cycler('color', ['k']) * cycler('linestyle', ['-', '--', ':', '-.']) * cycler('marker', [',']))
monochrome = monochromeNoMarker.concat(monochromeWithMarker)

plt.set_cmap('gray')
# Overriding styles for current script
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.bottom'] = False
plt.rcParams['axes.spines.left'] = False
plt.rcParams['figure.figsize'] = (12,5)
mpl.rcParams['figure.dpi']= 300
plt.rcParams['axes.prop_cycle'] = monochrome
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def cal_one_p(p):
    return np.mean(p.delays), np.max(p.delays)

def cal_vdr(ps, tg):
    if type(ps) is not list:
        ps = [ps]
    total_vehPass = 0
    total_tg = 0
    for p in ps:
        total_vehPass += p.vehPass
        total_tg += tg
    return total_vehPass / total_tg * 3600

def get_data_array(p,tg):
    delaymean, delaymax = cal_one_p(p)
    return [delaymean, delaymax, cal_vdr(p, tg)]

# %%
simulation_time = 120 # seconds
n = 200 # number of vehicles
intended_speed = 80 * 1000/3600 # intended speed / speed limit of the road
sim = Simulation(time = simulation_time, avStep = 100)


LRT = [1.34, -1.34]
HSR = [0.58, -0.54]

human_profile = [1.7, -2.0]
av_profile = LRT

paras={
    'v_intend': intended_speed,
    'human_max_acc': human_profile[0],
    'human_max_dec': human_profile[1],
    'max_acc': av_profile[0],
    'max_dec': av_profile[1],
    'tsys': 0.8,
    'human_T': 1.8,
    'AV_T': 1.2
}


human = sim.run_human_simulation(n, paras)
print(get_data_array(human,simulation_time))

simulation_time = 30 # seconds
n = 200 # number of vehicles
intended_speed = 80 * 1000/3600 # intended speed / speed limit of the road
sim = Simulation(time = simulation_time, avStep = 100)


LRT = [1.34, -1.34]
HSR = [0.58, -0.54]

human_profile = [1.7, -2.0]
av_profile = LRT

paras={
    'v_intend': intended_speed,
    'human_max_acc': human_profile[0],
    'human_max_dec': human_profile[1],
    'max_acc': av_profile[0],
    'max_dec': av_profile[1],
    'tsys': 0.8,
    'human_T': 1.8,
    'AV_T': 1.2
}


human1 = sim.run_human_simulation(n, paras)
print(get_data_array(human1,simulation_time))
# Out:
# [0.08660837488857373, 0.23098390624210402, 1830.0]
# [0.11179133241939057, 0.24758217203063762, 1800.0]

# %%
human_ps = []
av_ps = []
cav_ps = []
start_vm = 40
end_vm = 100
start_tg = 20
end_tg = 120
gran = 2
secondLoop = int(-(start_vm - end_vm) / gran ) + 1
totalLoop = int((end_tg - start_tg) / gran) + 1
print(totalLoop, secondLoop)
xs_tg = [start_tg + i * gran for i in range(totalLoop)]
ys_vm = [start_vm + j * gran for j in range(secondLoop)]
# Out:
# 51 31

# %%
human_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
human_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
human_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)
av_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
av_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
av_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)


for col in xs_tg:
    tg = col
    sim = Simulation(time = tg, avStep = 100)
    for idx in ys_vm:
        paras['v_intend'] = idx
        print(col,idx)
        av = sim.run_av_simulation(n, paras)
        cav = sim.run_cav_simulation(n, paras)
        human = sim.run_human_simulation(n, paras)
        human=get_data_array(human,tg)
        av=get_data_array(av, tg)
        cav=get_data_array(cav, tg)
        human_avg_delay.at[idx, col] = human[0]
        human_max_delay.at[idx, col] = human[1]
        human_vdr.at[idx, col] = human[2]
        av_avg_delay.at[idx, col] = av[0]
        av_max_delay.at[idx, col] = av[1]
        av_vdr.at[idx, col] = av[2]
        cav_avg_delay.at[idx, col] = cav[0]
        cav_max_delay.at[idx, col] = cav[1]
        cav_vdr.at[idx, col] = cav[2]
# Out:
# 20 40
# 20 42
# 20 44
# 20 46
# 20 48
# 20 50
# 20 52
# 20 54
# 20 56
# 20 58
# 20 60
# 20 62
# 20 64
# 20 66
# 20 68
# 20 70
# 20 72
# 20 74
# 20 76
# 20 78
# 20 80
# 20 82
# 20 84
# 20 86
# 20 88
# 20 90
# 20 92
# 20 94
# 20 96
# 20 98
# 20 100
# 22 40
# 22 42
# 22 44
# 22 46
# 22 48
# 22 50
# 22 52
# 22 54
# 22 56
# 22 58
# 22 60
# 22 62
# 22 64
# 22 66
# 22 68
# 22 70
# 22 72
# 22 74
# 22 76
# 22 78
# 22 80
# 22 82
# 22 84
# 22 86
# 22 88
# 22 90
# 22 92
# 22 94
# 22 96
# 22 98
# 22 100
# 24 40
# 24 42
# 24 44
# 24 46
# 24 48
# 24 50
# 24 52
# 24 54
# 24 56
# 24 58
# 24 60
# 24 62
# 24 64
# 24 66
# 24 68
# 24 70
# 24 72
# 24 74
# 24 76
# 24 78
# 24 80
# 24 82
# 24 84
# 24 86
# 24 88
# 24 90
# 24 92
# 24 94
# 24 96
# 24 98
# 24 100
# 26 40
# 26 42
# 26 44
# 26 46
# 26 48
# 26 50
# 26 52
# 26 54
# 26 56
# 26 58
# 26 60
# 26 62
# 26 64
# 26 66
# 26 68
# 26 70
# 26 72
# 26 74
# 26 76
# 26 78
# 26 80
# 26 82
# 26 84
# 26 86
# 26 88
# 26 90
# 26 92
# 26 94
# 26 96
# 26 98
# 26 100
# 28 40
# 28 42
# 28 44
# 28 46
# 28 48
# 28 50
# 28 52
# 28 54
# 28 56
# 28 58
# 28 60
# 28 62
# 28 64
# 28 66
# 28 68
# 28 70
# 28 72
# 28 74
# 28 76
# 28 78
# 28 80
# 28 82
# 28 84
# 28 86
# 28 88
# 28 90
# 28 92
# 28 94
# 28 96
# 28 98
# 28 100
# 30 40
# 30 42
# 30 44
# 30 46
# 30 48
# 30 50
# 30 52
# 30 54
# 30 56
# 30 58
# 30 60
# 30 62
# 30 64
# 30 66
# 30 68
# 30 70
# 30 72
# 30 74
# 30 76
# 30 78
# 30 80
# 30 82
# 30 84
# 30 86
# 30 88
# 30 90
# 30 92
# 30 94
# 30 96
# 30 98
# 30 100
# 32 40
# 32 42
# 32 44
# 32 46
# 32 48
# 32 50
# 32 52
# 32 54
# 32 56
# 32 58
# 32 60
# 32 62
# 32 64
# 32 66
# 32 68
# 32 70
# 32 72
# 32 74
# 32 76
# 32 78
# 32 80
# 32 82
# 32 84
# 32 86
# 32 88
# 32 90
# 32 92
# 32 94
# 32 96
# 32 98
# 32 100
# 34 40
# 34 42
# 34 44
# 34 46
# 34 48
# 34 50
# 34 52
# 34 54
# 34 56
# 34 58
# 34 60
# 34 62
# 34 64
# 34 66
# 34 68
# 34 70
# 34 72
# 34 74
# 34 76
# 34 78
# 34 80
# 34 82
# 34 84
# 34 86
# 34 88
# 34 90
# 34 92
# 34 94
# 34 96
# 34 98
# 34 100
# 36 40
# 36 42
# 36 44
# 36 46
# 36 48
# 36 50
# 36 52
# 36 54
# 36 56
# 36 58
# 36 60
# 36 62
# 36 64
# 36 66
# 36 68
# 36 70
# 36 72
# 36 74
# 36 76
# 36 78
# 36 80
# 36 82
# 36 84
# 36 86
# 36 88
# 36 90
# 36 92
# 36 94
# 36 96
# 36 98
# 36 100
# 38 40
# 38 42
# 38 44
# 38 46
# 38 48
# 38 50
# 38 52
# 38 54
# 38 56
# 38 58
# 38 60
# 38 62
# 38 64
# 38 66
# 38 68
# 38 70
# 38 72
# 38 74
# 38 76
# 38 78
# 38 80
# 38 82
# 38 84
# 38 86
# 38 88
# 38 90
# 38 92
# 38 94
# 38 96
# 38 98
# 38 100
# 40 40
# 40 42
# 40 44
# 40 46
# 40 48
# 40 50
# 40 52
# 40 54
# 40 56
# 40 58
# 40 60
# 40 62
# 40 64
# 40 66
# 40 68
# 40 70
# 40 72
# 40 74
# 40 76
# 40 78
# 40 80
# 40 82
# 40 84
# 40 86
# 40 88
# 40 90
# 40 92
# 40 94
# 40 96
# 40 98
# 40 100
# 42 40
# 42 42
# 42 44
# 42 46
# 42 48
# 42 50
# 42 52
# 42 54
# 42 56
# 42 58
# 42 60
# 42 62
# 42 64
# 42 66
# 42 68
# 42 70
# 42 72
# 42 74
# 42 76
# 42 78
# 42 80
# 42 82
# 42 84
# 42 86
# 42 88
# 42 90
# 42 92
# 42 94
# 42 96
# 42 98
# 42 100
# 44 40
# 44 42
# 44 44
# 44 46
# 44 48
# 44 50
# 44 52
# 44 54
# 44 56
# 44 58
# 44 60
# 44 62
# 44 64
# 44 66
# 44 68
# 44 70
# 44 72
# 44 74
# 44 76
# 44 78
# 44 80
# 44 82
# 44 84
# 60 80
# 60 82
# 60 84
# 60 86
# 60 88
# 60 90
# 60 92
# 60 94
# 60 96
# 60 98
# 60 100
# 62 40
# 62 42
# 62 44
# 62 46
# 62 48
# 62 50
# 62 52
# 62 54
# 62 56
# 62 58
# 62 60
# 62 62
# 62 64
# 62 66
# 62 68
# 62 70
# 62 72
# 62 74
# 62 76
# 62 78
# 62 80
# 62 82
# 62 84
# 62 86
# 62 88
# 62 90
# 62 92
# 62 94
# 62 96
# 62 98
# 62 100
# 64 40
# 64 42
# 64 44
# 64 46
# 64 48
# 64 50
# 64 52
# 64 54
# 64 56
# 64 58
# 64 60
# 64 62
# 64 64
# 64 66
# 64 68
# 64 70
# 64 72
# 64 74
# 64 76
# 64 78
# 64 80
# 64 82
# 64 84
# 64 86
# 64 88
# 64 90
# 64 92
# 64 94
# 64 96
# 64 98
# 64 100
# 66 40
# 66 42
# 66 44
# 66 46
# 66 48
# 66 50
# 66 52
# 66 54
# 66 56
# 66 58
# 66 60
# 66 62
# 66 64
# 66 66
# 66 68
# 66 70
# 66 72
# 66 74
# 66 76
# 66 78
# 66 80
# 66 82
# 66 84
# 66 86
# 66 88
# 66 90
# 66 92
# 66 94
# 66 96
# 66 98
# 66 100
# 68 40
# 68 42
# 68 44
# 68 46
# 68 48
# 68 50
# 68 52
# 68 54
# 68 56
# 68 58
# 68 60
# 68 62
# 68 64
# 68 66
# 68 68
# 68 70
# 68 72
# 68 74
# 68 76
# 68 78
# 68 80
# 68 82
# 68 84
# 68 86
# 68 88
# 68 90
# 68 92
# 68 94
# 68 96
# 68 98
# 68 100
# 70 40
# 70 42
# 70 44
# 70 46
# 70 48
# 70 50
# 70 52
# 70 54
# 70 56
# 70 58
# 70 60
# 70 62
# 70 64
# 70 66
# 70 68
# 70 70
# 70 72
# 70 74
# 70 76
# 70 78
# 70 80
# 70 82
# 70 84
# 70 86
# 70 88
# 70 90
# 70 92
# 70 94
# 70 96
# 70 98
# 70 100
# 72 40
# 72 42
# 72 44
# 72 46
# 72 48
# 72 50
# 72 52
# 72 54
# 72 56
# 72 58
# 72 60
# 72 62
# 72 64
# 72 66
# 72 68
# 72 70
# 72 72
# 72 74
# 72 76
# 72 78
# 72 80
# 72 82
# 72 84
# 72 86
# 72 88
# 72 90
# 72 92
# 72 94
# 72 96
# 72 98
# 72 100
# 74 40
# 74 42
# 74 44
# 74 46
# 74 48
# 74 50
# 74 52
# 74 54
# 74 56
# 74 58
# 74 60
# 74 62
# 74 64
# 74 66
# 74 68
# 74 70
# 74 72
# 74 74
# 74 76
# 74 78
# 74 80
# 74 82
# 74 84
# 74 86
# 74 88
# 74 90
# 74 92
# 74 94
# 74 96
# 74 98
# 74 100
# 76 40
# 76 42
# 76 44
# 76 46
# 76 48
# 76 50
# 76 52
# 76 54
# 76 56
# 76 58
# 76 60
# 76 62
# 76 64
# 76 66
# 76 68
# 76 70
# 76 72
# 92 68
# 92 70
# 92 72
# 92 74
# 92 76
# 92 78
# 92 80
# 92 82
# 92 84
# 92 86
# 92 88
# 92 90
# 92 92
# 92 94
# 92 96
# 92 98
# 92 100
# 94 40
# 94 42
# 94 44
# 94 46
# 94 48
# 94 50
# 94 52
# 94 54
# 94 56
# 94 58
# 94 60
# 94 62
# 94 64
# 94 66
# 94 68
# 94 70
# 94 72
# 94 74
# 94 76
# 94 78
# 94 80
# 94 82
# 94 84
# 94 86
# 94 88
# 94 90
# 94 92
# 94 94
# 94 96
# 94 98
# 94 100
# 96 40
# 96 42
# 96 44
# 96 46
# 96 48
# 96 50
# 96 52
# 96 54
# 96 56
# 96 58
# 96 60
# 96 62
# 96 64
# 96 66
# 96 68
# 96 70
# 96 72
# 96 74
# 96 76
# 96 78
# 96 80
# 96 82
# 96 84
# 96 86
# 96 88
# 96 90
# 96 92
# 96 94
# 96 96
# 96 98
# 96 100
# 98 40
# 98 42
# 98 44
# 98 46
# 98 48
# 98 50
# 98 52
# 98 54
# 98 56
# 98 58
# 98 60
# 98 62
# 98 64
# 98 66
# 98 68
# 98 70
# 98 72
# 98 74
# 98 76
# 98 78
# 98 80
# 98 82
# 98 84
# 98 86
# 98 88
# 98 90
# 98 92
# 98 94
# 98 96
# 98 98
# 98 100
# 100 40
# 100 42
# 100 44
# 100 46
# 100 48
# 100 50
# 100 52
# 100 54
# 100 56
# 100 58
# 100 60
# 100 62
# 100 64
# 100 66
# 100 68
# 100 70
# 100 72
# 100 74
# 100 76
# 100 78
# 100 80
# 100 82
# 100 84
# 100 86
# 100 88
# 100 90
# 100 92
# 100 94
# 100 96
# 100 98
# 100 100
# 102 40
# 102 42
# 102 44
# 102 46
# 102 48
# 102 50
# 102 52
# 102 54
# 102 56
# 102 58
# 102 60
# 102 62
# 102 64
# 102 66
# 102 68
# 102 70
# 102 72
# 102 74
# 102 76
# 102 78
# 102 80
# 102 82
# 102 84
# 102 86
# 102 88
# 102 90
# 102 92
# 102 94
# 102 96
# 102 98
# 102 100
# 104 40
# 104 42
# 104 44
# 104 46
# 104 48
# 104 50
# 104 52
# 104 54
# 104 56
# 104 58
# 104 60
# 104 62
# 104 64
# 104 66
# 104 68
# 104 70
# 104 72
# 104 74
# 104 76
# 104 78
# 104 80
# 104 82
# 104 84
# 104 86
# 104 88
# 104 90
# 104 92
# 104 94
# 104 96
# 104 98
# 104 100
# 106 40
# 106 42
# 106 44
# 106 46
# 106 48
# 106 50
# 106 52
# 106 54
# 106 56
# 106 58
# 106 60
# 106 62
# 106 64
# 106 66
# 106 68
# 106 70
# 106 72
# 106 74
# 106 76
# 106 78
# 106 80
# 106 82
# 106 84
# 106 86
# 106 88
# 106 90
# 106 92
# 106 94
# 106 96
# 106 98
# 106 100
# 108 40
# 108 42
# 108 44
# 108 46
# 108 48
# 108 50
# 108 52
# 108 54
# 108 56
# 108 58
# 108 60
# 108 62
# 108 64
# 108 66
# 108 68
# 108 70
# 108 72
# 108 74
# 108 76
# 108 78
# 108 80
# 108 82
# 108 84
# 108 86
# 108 88
# 108 90
# 108 92
# 108 94
# 108 96
# 108 98
# 108 100
# 110 40
# 110 42
# 110 44
# 110 46
# 110 48
# 110 50
# 110 52
# 110 54
# 110 56
# 110 58
# 110 60
# 110 62
# 110 64
# 110 66
# 110 68
# 110 70
# 110 72
# 110 74
# 110 76
# 110 78
# 110 80
# 110 82
# 110 84
# 110 86
# 110 88
# 110 90
# 110 92
# 110 94
# 110 96
# 110 98
# 110 100
# 112 40
# 112 42
# 112 44
# 112 46
# 112 48
# 112 50
# 112 52
# 112 54
# 112 56
# 112 58
# 112 60
# 112 62
# 112 64
# 112 66
# 112 68
# 112 70
# 112 72
# 112 74
# 112 76
# 112 78
# 112 80
# 112 82
# 112 84
# 112 86
# 112 88
# 112 90
# 112 92
# 112 94
# 112 96
# 112 98
# 112 100
# 114 40
# 114 42
# 114 44
# 114 46
# 114 48
# 114 50
# 114 52
# 114 54
# 114 56
# 114 58
# 114 60
# 114 62
# 114 64
# 114 66
# 114 68
# 114 70
# 114 72
# 114 74
# 114 76
# 114 78
# 114 80
# 114 82
# 114 84
# 114 86
# 114 88
# 114 90
# 114 92
# 114 94
# 114 96
# 114 98
# 114 100
# 116 40
# 116 42
# 116 44
# 116 46
# 116 48
# 116 50
# 116 52
# 116 54
# 116 56
# 116 58
# 116 60
# 116 62
# 116 64
# 116 66
# 116 68
# 116 70
# 116 72
# 116 74
# 116 76
# 116 78
# 116 80
# 116 82
# 116 84
# 116 86
# 116 88
# 116 90
# 116 92
# 116 94
# 116 96
# 116 98
# 116 100
# 118 40
# 118 42
# 118 44
# 118 46
# 118 48
# 118 50
# 118 52
# 118 54
# 118 56
# 118 58
# 118 60
# 118 62
# 118 64
# 118 66
# 118 68
# 118 70
# 118 72
# 118 74
# 118 76
# 118 78
# 118 80
# 118 82
# 118 84
# 118 86
# 118 88
# 118 90
# 118 92
# 118 94
# 118 96
# 118 98
# 118 100
# 120 40
# 120 42
# 120 44
# 120 46
# 120 48
# 120 50
# 120 52
# 120 54
# 120 56
# 120 58
# 120 60
# 120 62
# 120 64
# 120 66
# 120 68
# 120 70
# 120 72
# 120 74
# 120 76
# 120 78
# 120 80
# 120 82
# 120 84
# 120 86
# 120 88
# 120 90
# 120 92
# 120 94
# 120 96
# 120 98
# 120 100

# %%
cav_avg_delay
# Out:
#            20         22         24         26         28         30   \
# 40   0.0822221  0.0773848  0.0715987  0.0681397  0.0636665  0.0613952
# 42   0.0834126  0.0785753  0.0727891  0.0693302  0.0647933  0.0623066
# 44   0.0844948  0.0796575  0.0738714  0.0704124  0.0658755  0.0632603
# 46    0.085483  0.0806457  0.0748595  0.0714006  0.0668637  0.0642477
# 48   0.0863888  0.0815515  0.0757653  0.0723064  0.0677695  0.0651535
# 78   0.0353269  0.0346955  0.0345781  0.0339847  0.0338852  0.0337909
# 80   0.0353607  0.0347212  0.0345961  0.0344774  0.0338884  0.0337871
# 82   0.0354053  0.0347577  0.0346251  0.0344991  0.0339029  0.0337947
# 84   0.0354595  0.0348042  0.0346641   0.034531  0.0339277  0.0338128
# 86   0.0355227  0.0353612  0.0347124  0.0345723  0.0344388  0.0338406
# 88   0.0355936   0.035425  0.0347689   0.034622  0.0344818   0.033877
# 90   0.0356715  0.0354958  0.0348327  0.0346791  0.0345325  0.0339212
# 92   0.0357554  0.0355729  0.0349028  0.0347428  0.0345899  0.0339723
# 94   0.0358444  0.0356553  0.0349785  0.0348121  0.0346531  0.0340293
# 96   0.0359379  0.0357423  0.0350591  0.0348866  0.0347216  0.0345636
# 98   0.0360359   0.035834  0.0356409  0.0349662  0.0347954  0.0346318
# 100  0.0361383  0.0359306  0.0357317  0.0350511  0.0348747  0.0347056
#
#            116        118        120
# 40   0.0338649  0.0335305   0.033643
# 42   0.0337786  0.0334299  0.0335288
# 44   0.0337456  0.0333825  0.0330319
# 46   0.0333111  0.0333837   0.033019
# 48   0.0333705  0.0334298  0.0330506
# 50   0.0334713  0.0330725  0.0331235
# 52   0.0331588  0.0331964  0.0327968
# 54   0.0333314   0.032911  0.0329412
# 56   0.0330847   0.033101  0.0326804
# 58   0.0333188  0.0328762  0.0328861
# 60   0.0331278  0.0331235  0.0326812
# 62   0.0334156  0.0329502  0.0329404
# 64   0.0332721  0.0328002  0.0327831
# 66   0.0331503  0.0331182  0.0326474
# 68   0.0330483  0.0330089  0.0329726
# 70     0.03342  0.0329181  0.0328747
# 72   0.0333529  0.0332941  0.0327942
# 74   0.0333017  0.0332358  0.0327296
# 76   0.0332651  0.0331925  0.0331238
# 78   0.0332422  0.0331628  0.0330876
# 80    0.033691  0.0331456   0.033064
# 82   0.0336919  0.0331401  0.0330522
# 84   0.0337035  0.0331452  0.0330512
# 86   0.0337248  0.0336145  0.0330602
# 88    0.033755  0.0336386  0.0330783
# 90   0.0337931  0.0336707  0.0331045
# 92   0.0338382    0.03371  0.0331379
# 94   0.0338894  0.0337555  0.0336273
# 96   0.0339463  0.0338069  0.0336733
# 98   0.0340089  0.0338641  0.0337253
# 100  0.0340773  0.0339273  0.0337834
#
# [31 rows x 51 columns]

# %%
subFolder = "SG2/"
av_avg_delay.to_csv(subFolder+'av_avg_delay.csv')
av_max_delay.to_csv(subFolder+'av_max_delay.csv')
av_vdr.to_csv(subFolder+'av_vdr.csv')
cav_avg_delay.to_csv(subFolder+'cav_avg_delay.csv')
cav_max_delay.to_csv(subFolder+'cav_max_delay.csv')
cav_vdr.to_csv(subFolder+'cav_vdr.csv')
h_avg_delay.to_csv(subFolder+'cav_avg_delay.csv')
cav_max_delay.to_csv(subFolder+'cav_max_delay.csv')
cav_vdr.to_csv(subFolder+'cav_vdr.csv')
