# %%
import matplotlib.pyplot as plt
from Objects.Simulation import Simulation
import numpy as np
import pandas as pd
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab
# %matplotlib inline

from matplotlib import lines, markers
from cycler import cycler

# Create cycler object. Use any styling from above you please
monochromeWithMarker = (cycler('color', ['k']) * cycler('linestyle', ['-', '--', ':', '-.']) * cycler('marker', [ '.' ,'^']))
monochromeNoMarker = (cycler('color', ['k']) * cycler('linestyle', ['-', '--', ':', '-.']) * cycler('marker', [',']))
monochrome = monochromeNoMarker.concat(monochromeWithMarker)

plt.set_cmap('gray')
# Overriding styles for current script
plt.rcParams['axes.grid'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.bottom'] = False
plt.rcParams['axes.spines.left'] = False
plt.rcParams['figure.figsize'] = (12,5)
mpl.rcParams['figure.dpi']= 300
plt.rcParams['axes.prop_cycle'] = monochrome
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def cal_one_p(p):
    return np.mean(p.delays), np.max(p.delays)

def cal_vdr(ps, tg):
    if type(ps) is not list:
        ps = [ps]
    total_vehPass = 0
    total_tg = 0
    for p in ps:
        total_vehPass += p.vehPass
        total_tg += tg
    return total_vehPass / total_tg * 3600

def get_data_array(p,tg):
    delaymean, delaymax = cal_one_p(p)
    return [delaymean, delaymax, cal_vdr(p, tg)]

# %%
simulation_time = 120 # seconds
n = 200 # number of vehicles
intended_speed = 80 * 1000/3600 # intended speed / speed limit of the road
sim = Simulation(time = simulation_time, avStep = 100)


LRT = [1.34, -1.34]
HSR = [0.58, -0.54]

human_profile = [1.7, -2.0]
av_profile = LRT

paras={
    'v_intend': intended_speed,
    'human_max_acc': human_profile[0],
    'human_max_dec': human_profile[1],
    'max_acc': av_profile[0],
    'max_dec': av_profile[1],
    'tsys': 0.8,
    'human_T': 1.8,
    'AV_T': 1.2
}


human = sim.run_human_simulation(n, paras)
print(get_data_array(human,simulation_time))

simulation_time = 30 # seconds
n = 200 # number of vehicles
intended_speed = 80 * 1000/3600 # intended speed / speed limit of the road
sim = Simulation(time = simulation_time, avStep = 100)


LRT = [1.34, -1.34]
HSR = [0.58, -0.54]

human_profile = [1.7, -2.0]
av_profile = HSR

paras={
    'v_intend': intended_speed,
    'human_max_acc': human_profile[0],
    'human_max_dec': human_profile[1],
    'max_acc': av_profile[0],
    'max_dec': av_profile[1],
    'tsys': 0.8,
    'human_T': 1.8,
    'AV_T': 1.2
}


human1 = sim.run_human_simulation(n, paras)
print(get_data_array(human1,simulation_time))
# Out:
# [0.08660837488857373, 0.23098390624210402, 1830.0]
# [0.11179133241939057, 0.24758217203063762, 1800.0]

# %%
human_ps = []
av_ps = []
cav_ps = []
start_vm = 40
end_vm = 100
start_tg = 20
end_tg = 120
gran = 2
secondLoop = int(-(start_vm - end_vm) / gran ) + 1
totalLoop = int((end_tg - start_tg) / gran) + 1
print(totalLoop, secondLoop)
xs_tg = [start_tg + i * gran for i in range(totalLoop)]
ys_vm = [start_vm + j * gran for j in range(secondLoop)]
# Out:
# 51 31

# %%
# calculate LRT

# human_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# human_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# human_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)
# av_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# av_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# av_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)
# cav_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# cav_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
# cav_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)


# for col in xs_tg:
#     tg = col
#     sim = Simulation(time = tg, avStep = 100)
#     for idx in ys_vm:
#         paras['v_intend'] = idx
#         print(col,idx)
#         av = sim.run_av_simulation(n, paras)
#         cav = sim.run_cav_simulation(n, paras)
#         human = sim.run_human_simulation(n, paras)
#         human=get_data_array(human,tg)
#         av=get_data_array(av, tg)
#         cav=get_data_array(cav, tg)
#         human_avg_delay.at[idx, col] = human[0]
#         human_max_delay.at[idx, col] = human[1]
#         human_vdr.at[idx, col] = human[2]
#         av_avg_delay.at[idx, col] = av[0]
#         av_max_delay.at[idx, col] = av[1]
#         av_vdr.at[idx, col] = av[2]
#         cav_avg_delay.at[idx, col] = cav[0]
#         cav_max_delay.at[idx, col] = cav[1]
#         cav_vdr.at[idx, col] = cav[2]

# %%
# calculate HSR:
av_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
av_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
av_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_avg_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_max_delay = pd.DataFrame(index = ys_vm, columns=xs_tg)
cav_vdr = pd.DataFrame(index = ys_vm, columns=xs_tg)


for col in xs_tg:
    tg = col
    sim = Simulation(time = tg, avStep = 100)
    for idx in ys_vm:
        paras['v_intend'] = idx
        print(col,idx)
        av = sim.run_av_simulation(n, paras)
        cav = sim.run_cav_simulation(n, paras)
        av=get_data_array(av, tg)
        cav=get_data_array(cav, tg)
        av_avg_delay.at[idx, col] = av[0]
        av_max_delay.at[idx, col] = av[1]
        av_vdr.at[idx, col] = av[2]
        cav_avg_delay.at[idx, col] = cav[0]
        cav_max_delay.at[idx, col] = cav[1]
        cav_vdr.at[idx, col] = cav[2]
# Out:
# 20 40
# 20 42
# 20 44
# 20 46
# 20 48
# 20 50
# 20 52
# 20 54
# 20 56
# 20 58
# 20 60
# 20 62
# 20 64
# 20 66
# 20 68
# 20 70
# 20 72
# 20 74
# 20 76
# 20 78
# 20 80
# 20 82
# 20 84
# 20 86
# 20 88
# 20 90
# 20 92
# 20 94
# 20 96
# 20 98
# 20 100
# 22 40
# 22 42
# 22 44
# 22 46
# 22 48
# 22 50
# 22 52
# 22 54
# 22 56
# 22 58
# 22 60
# 22 62
# 22 64
# 22 66
# 22 68
# 22 70
# 22 72
# 22 74
# 22 76
# 22 78
# 22 80
# 22 82
# 22 84
# 22 86
# 22 88
# 22 90
# 22 92
# 22 94
# 22 96
# 22 98
# 22 100
# 24 40
# 24 42
# 24 44
# 24 46
# 24 48
# 24 50
# 24 52
# 24 54
# 24 56
# 24 58
# 24 60
# 24 62
# 24 64
# 24 66
# 24 68
# 24 70
# 24 72
# 24 74
# 24 76
# 24 78
# 24 80
# 24 82
# 24 84
# 24 86
# 24 88
# 24 90
# 24 92
# 24 94
# 24 96
# 24 98
# 24 100
# 26 40
# 26 42
# 26 44
# 26 46
# 26 48
# 26 50
# 26 52
# 26 54
# 26 56
# 26 58
# 26 60
# 26 62
# 26 64
# 26 66
# 26 68
# 26 70
# 26 72
# 26 74
# 26 76
# 26 78
# 26 80
# 26 82
# 26 84
# 26 86
# 26 88
# 26 90
# 26 92
# 26 94
# 26 96
# 26 98
# 26 100
# 28 40
# 28 42
# 28 44
# 28 46
# 28 48
# 28 50
# 28 52
# 28 54
# 28 56
# 28 58
# 28 60
# 28 62
# 28 64
# 28 66
# 28 68
# 28 70
# 28 72
# 28 74
# 28 76
# 28 78
# 28 80
# 28 82
# 28 84
# 28 86
# 28 88
# 28 90
# 28 92
# 28 94
# 28 96
# 28 98
# 28 100
# 30 40
# 30 42
# 30 44
# 30 46
# 30 48
# 30 50
# 30 52
# 30 54
# 30 56
# 30 58
# 30 60
# 30 62
# 30 64
# 30 66
# 30 68
# 30 70
# 30 72
# 30 74
# 30 76
# 30 78
# 30 80
# 30 82
# 30 84
# 30 86
# 30 88
# 30 90
# 30 92
# 30 94
# 30 96
# 30 98
# 30 100
# 32 40
# 32 42
# 32 44
# 32 46
# 32 48
# 32 50
# 32 52
# 32 54
# 32 56
# 32 58
# 32 60
# 32 62
# 32 64
# 32 66
# 32 68
# 32 70
# 32 72
# 32 74
# 32 76
# 32 78
# 32 80
# 32 82
# 32 84
# 32 86
# 32 88
# 32 90
# 32 92
# 32 94
# 32 96
# 32 98
# 32 100
# 34 40
# 34 42
# 34 44
# 34 46
# 34 48
# 34 50
# 34 52
# 34 54
# 34 56
# 34 58
# 34 60
# 34 62
# 34 64
# 34 66
# 34 68
# 34 70
# 34 72
# 34 74
# 34 76
# 34 78
# 34 80
# 34 82
# 34 84
# 34 86
# 34 88
# 34 90
# 34 92
# 34 94
# 34 96
# 34 98
# 34 100
# 36 40
# 36 42
# 36 44
# 36 46
# 36 48
# 36 50
# 36 52
# 36 54
# 36 56
# 36 58
# 36 60
# 36 62
# 36 64
# 36 66
# 36 68
# 36 70
# 36 72
# 36 74
# 36 76
# 36 78
# 36 80
# 36 82
# 36 84
# 36 86
# 36 88
# 36 90
# 36 92
# 36 94
# 36 96
# 36 98
# 36 100
# 38 40
# 38 42
# 38 44
# 38 46
# 38 48
# 38 50
# 38 52
# 38 54
# 38 56
# 38 58
# 38 60
# 38 62
# 38 64
# 38 66
# 38 68
# 38 70
# 38 72
# 38 74
# 38 76
# 38 78
# 38 80
# 38 82
# 38 84
# 38 86
# 38 88
# 38 90
# 38 92
# 38 94
# 38 96
# 38 98
# 38 100
# 40 40
# 40 42
# 40 44
# 40 46
# 40 48
# 40 50
# 40 52
# 40 54
# 40 56
# 40 58
# 40 60
# 40 62
# 40 64
# 40 66
# 40 68
# 40 70
# 40 72
# 40 74
# 40 76
# 40 78
# 40 80
# 40 82
# 40 84
# 40 86
# 40 88
# 56 86
# 56 88
# 56 90
# 56 92
# 56 94
# 56 96
# 56 98
# 56 100
# 58 40
# 58 42
# 58 44
# 58 46
# 58 48
# 58 50
# 58 52
# 58 54
# 58 56
# 58 58
# 58 60
# 58 62
# 58 64
# 58 66
# 58 68
# 58 70
# 58 72
# 58 74
# 58 76
# 58 78
# 58 80
# 58 82
# 58 84
# 58 86
# 58 88
# 58 90
# 58 92
# 58 94
# 58 96
# 58 98
# 58 100
# 60 40
# 60 42
# 60 44
# 60 46
# 60 48
# 60 50
# 60 52
# 60 54
# 60 56
# 60 58
# 60 60
# 60 62
# 60 64
# 60 66
# 60 68
# 60 70
# 60 72
# 60 74
# 60 76
# 60 78
# 60 80
# 60 82
# 60 84
# 60 86
# 60 88
# 60 90
# 60 92
# 60 94
# 60 96
# 60 98
# 60 100
# 62 40
# 62 42
# 62 44
# 62 46
# 62 48
# 62 50
# 62 52
# 62 54
# 62 56
# 62 58
# 62 60
# 62 62
# 62 64
# 62 66
# 62 68
# 62 70
# 62 72
# 62 74
# 62 76
# 62 78
# 62 80
# 62 82
# 62 84
# 62 86
# 62 88
# 62 90
# 62 92
# 62 94
# 62 96
# 62 98
# 62 100
# 64 40
# 64 42
# 64 44
# 64 46
# 64 48
# 64 50
# 64 52
# 64 54
# 64 56
# 64 58
# 64 60
# 64 62
# 64 64
# 64 66
# 64 68
# 64 70
# 64 72
# 64 74
# 64 76
# 64 78
# 64 80
# 64 82
# 64 84
# 64 86
# 64 88
# 64 90
# 64 92
# 64 94
# 64 96
# 64 98
# 64 100
# 66 40
# 66 42
# 66 44
# 66 46
# 66 48
# 66 50
# 66 52
# 66 54
# 66 56
# 66 58
# 66 60
# 66 62
# 66 64
# 66 66
# 66 68
# 66 70
# 66 72
# 66 74
# 66 76
# 66 78
# 66 80
# 66 82
# 66 84
# 66 86
# 66 88
# 66 90
# 66 92
# 66 94
# 66 96
# 66 98
# 66 100
# 68 40
# 68 42
# 68 44
# 68 46
# 68 48
# 68 50
# 68 52
# 68 54
# 68 56
# 68 58
# 68 60
# 68 62
# 68 64
# 68 66
# 68 68
# 68 70
# 68 72
# 68 74
# 68 76
# 68 78
# 68 80
# 68 82
# 68 84
# 68 86
# 68 88
# 68 90
# 68 92
# 68 94
# 68 96
# 68 98
# 68 100
# 70 40
# 70 42
# 70 44
# 70 46
# 70 48
# 70 50
# 70 52
# 70 54
# 70 56
# 70 58
# 70 60
# 70 62
# 70 64
# 70 66
# 70 68
# 70 70
# 70 72
# 70 74
# 70 76
# 70 78
# 70 80
# 70 82
# 70 84
# 70 86
# 70 88
# 70 90
# 70 92
# 70 94
# 70 96
# 70 98
# 70 100
# 72 40
# 72 42
# 72 44
# 72 46
# 72 48
# 72 50
# 72 52
# 72 54
# 72 56
# 72 58
# 72 60
# 72 62
# 72 64
# 72 66
# 72 68
# 72 70
# 72 72
# 72 74
# 72 76
# 72 78
# 72 80
# 72 82
# 88 80
# 88 82
# 88 84
# 88 86
# 88 88
# 88 90
# 88 92
# 88 94
# 88 96
# 88 98
# 88 100
# 90 40
# 90 42
# 90 44
# 90 46
# 90 48
# 90 50
# 90 52
# 90 54
# 90 56
# 90 58
# 90 60
# 90 62
# 90 64
# 90 66
# 90 68
# 90 70
# 90 72
# 90 74
# 90 76
# 90 78
# 90 80
# 90 82
# 90 84
# 90 86
# 90 88
# 90 90
# 90 92
# 90 94
# 90 96
# 90 98
# 90 100
# 92 40
# 92 42
# 92 44
# 92 46
# 92 48
# 92 50
# 92 52
# 92 54
# 92 56
# 92 58
# 92 60
# 92 62
# 92 64
# 92 66
# 92 68
# 92 70
# 92 72
# 92 74
# 92 76
# 92 78
# 92 80
# 92 82
# 92 84
# 92 86
# 92 88
# 92 90
# 92 92
# 92 94
# 92 96
# 92 98
# 92 100
# 94 40
# 94 42
# 94 44
# 94 46
# 94 48
# 94 50
# 94 52
# 94 54
# 94 56
# 94 58
# 94 60
# 94 62
# 94 64
# 94 66
# 94 68
# 94 70
# 94 72
# 94 74
# 94 76
# 94 78
# 94 80
# 94 82
# 94 84
# 94 86
# 94 88
# 94 90
# 94 92
# 94 94
# 94 96
# 94 98
# 94 100
# 96 40
# 96 42
# 96 44
# 96 46
# 96 48
# 96 50
# 96 52
# 96 54
# 96 56
# 96 58
# 96 60
# 96 62
# 96 64
# 96 66
# 96 68
# 96 70
# 96 72
# 96 74
# 96 76
# 96 78
# 96 80
# 96 82
# 96 84
# 96 86
# 96 88
# 96 90
# 96 92
# 96 94
# 96 96
# 96 98
# 96 100
# 98 40
# 98 42
# 98 44
# 98 46
# 98 48
# 98 50
# 98 52
# 98 54
# 98 56
# 98 58
# 98 60
# 98 62
# 98 64
# 98 66
# 98 68
# 98 70
# 98 72
# 98 74
# 98 76
# 98 78
# 98 80
# 98 82
# 98 84
# 98 86
# 98 88
# 98 90
# 98 92
# 98 94
# 98 96
# 98 98
# 98 100
# 100 40
# 100 42
# 100 44
# 100 46
# 100 48
# 100 50
# 100 52
# 100 54
# 100 56
# 100 58
# 100 60
# 100 62
# 100 64
# 100 66
# 100 68
# 100 70
# 100 72
# 100 74
# 100 76
# 100 78
# 100 80
# 100 82
# 100 84
# 100 86
# 100 88
# 100 90
# 100 92
# 100 94
# 100 96
# 100 98
# 100 100
# 102 40
# 102 42
# 102 44
# 102 46
# 102 48
# 102 50
# 102 52
# 102 54
# 102 56
# 102 58
# 102 60
# 102 62
# 102 64
# 102 66
# 102 68
# 102 70
# 102 72
# 102 74
# 102 76
# 102 78
# 102 80
# 102 82
# 102 84
# 102 86
# 102 88
# 102 90
# 102 92
# 102 94
# 102 96
# 102 98
# 102 100
# 104 40
# 104 42
# 104 44
# 104 46
# 104 48
# 104 50
# 104 52
# 104 54
# 104 56
# 104 58
# 104 60
# 104 62
# 104 64
# 104 66
# 104 68
# 104 70
# 104 72
# 104 74
# 104 76
# 104 78
# 104 80
# 104 82
# 104 84
# 104 86
# 104 88
# 104 90
# 104 92
# 104 94
# 104 96
# 104 98
# 104 100
# 106 40
# 106 42
# 106 44
# 106 46
# 106 48
# 106 50
# 106 52
# 106 54
# 106 56
# 106 58
# 106 60
# 106 62
# 106 64
# 106 66
# 106 68
# 106 70
# 106 72
# 106 74
# 106 76
# 106 78
# 106 80
# 106 82
# 106 84
# 106 86
# 106 88
# 106 90
# 106 92
# 106 94
# 106 96
# 106 98
# 106 100
# 108 40
# 108 42
# 108 44
# 108 46
# 108 48
# 108 50
# 108 52
# 108 54
# 108 56
# 108 58
# 108 60
# 108 62
# 108 64
# 108 66
# 108 68
# 108 70
# 108 72
# 108 74
# 108 76
# 108 78
# 108 80
# 108 82
# 108 84
# 108 86
# 108 88
# 108 90
# 108 92
# 108 94
# 108 96
# 108 98
# 108 100
# 110 40
# 110 42
# 110 44
# 110 46
# 110 48
# 110 50
# 110 52
# 110 54
# 110 56
# 110 58
# 110 60
# 110 62
# 110 64
# 110 66
# 110 68
# 110 70
# 110 72
# 110 74
# 110 76
# 110 78
# 110 80
# 110 82
# 110 84
# 110 86
# 110 88
# 110 90
# 110 92
# 110 94
# 110 96
# 110 98
# 110 100
# 112 40
# 112 42
# 112 44
# 112 46
# 112 48
# 112 50
# 112 52
# 112 54
# 112 56
# 112 58
# 112 60
# 112 62
# 112 64
# 112 66
# 112 68
# 112 70
# 112 72
# 112 74
# 112 76
# 112 78
# 112 80
# 112 82
# 112 84
# 112 86
# 112 88
# 112 90
# 112 92
# 112 94
# 112 96
# 112 98
# 112 100
# 114 40
# 114 42
# 114 44
# 114 46
# 114 48
# 114 50
# 114 52
# 114 54
# 114 56
# 114 58
# 114 60
# 114 62
# 114 64
# 114 66
# 114 68
# 114 70
# 114 72
# 114 74
# 114 76
# 114 78
# 114 80
# 114 82
# 114 84
# 114 86
# 114 88
# 114 90
# 114 92
# 114 94
# 114 96
# 114 98
# 114 100
# 116 40
# 116 42
# 116 44
# 116 46
# 116 48
# 116 50
# 116 52
# 116 54
# 116 56
# 116 58
# 116 60
# 116 62
# 116 64
# 116 66
# 116 68
# 116 70
# 116 72
# 116 74
# 116 76
# 116 78
# 116 80
# 116 82
# 116 84
# 116 86
# 116 88
# 116 90
# 116 92
# 116 94
# 116 96
# 116 98
# 116 100
# 118 40
# 118 42
# 118 44
# 118 46
# 118 48
# 118 50
# 118 52
# 118 54
# 118 56
# 118 58
# 118 60
# 118 62
# 118 64
# 118 66
# 118 68
# 118 70
# 118 72
# 118 74
# 118 76
# 118 78
# 118 80
# 118 82
# 118 84
# 118 86
# 118 88
# 118 90
# 118 92
# 118 94
# 118 96
# 118 98
# 118 100
# 120 40
# 120 42
# 120 44
# 120 46
# 120 48
# 120 50
# 120 52
# 120 54
# 120 56
# 120 58
# 120 60
# 120 62
# 120 64
# 120 66
# 120 68
# 120 70
# 120 72
# 120 74
# 58   0.0547766   0.053827  0.0535126  0.0526133  0.0517427  0.0514762
# 60   0.0553085  0.0543561  0.0540376  0.0531294  0.0522492  0.0519702
# 62   0.0558027  0.0548592  0.0545396  0.0536275   0.052743   0.052459
# 64   0.0562227  0.0553002  0.0549982  0.0540912  0.0532046  0.0529186
# 66    0.056687  0.0557146  0.0553987  0.0545155  0.0536448  0.0533623
# 68   0.0571326  0.0561603  0.0558204  0.0548903  0.0546084  0.0537577
# 70   0.0575528  0.0565804  0.0562405  0.0553105  0.0549918  0.0541025
# 72   0.0579496  0.0569773  0.0566374  0.0557073  0.0553886  0.0544976
# 74    0.058325  0.0573526  0.0570127  0.0560827   0.055764   0.054873
# 76   0.0586806  0.0577083  0.0573684  0.0564383  0.0561196  0.0552286
# 78    0.059018  0.0580456  0.0577057  0.0567757   0.056457   0.055566
# 80   0.0593385  0.0583662  0.0580262  0.0570962  0.0567775  0.0558865
# 82   0.0596434   0.058671  0.0583311  0.0574011  0.0570824  0.0561914
# 84   0.0599337  0.0589614  0.0586215  0.0576914  0.0573728  0.0564817
# 86   0.0602106  0.0592383  0.0588983  0.0579683  0.0576496  0.0567586
# 88   0.0604749  0.0595025  0.0591626  0.0582325  0.0579139  0.0570229
# 90   0.0607274  0.0597551  0.0594151  0.0584851  0.0581664  0.0572754
# 92   0.0609689  0.0599966  0.0596567  0.0587266   0.058408  0.0575169
# 94   0.0612002  0.0602279  0.0598879  0.0589579  0.0586392  0.0577482
# 96   0.0614218  0.0604495  0.0601096  0.0591795  0.0588609  0.0579698
# 98   0.0616344  0.0606621  0.0603222  0.0593921  0.0590735  0.0581824
# 100  0.0618385  0.0608662  0.0605262  0.0595962  0.0592775  0.0583865
#
#            120
# 40   0.0468086
# 42   0.0471234
# 44   0.0474813
# 46   0.0478748
# 48   0.0482982
# 50   0.0487439
# 52   0.0492076
# 54   0.0496831
# 56   0.0501661
# 58   0.0506522
# 60   0.0511354
# 62   0.0516141
# 64   0.0520706
# 66   0.0525123
# 68   0.0529183
# 70   0.0532817
# 72   0.0536307
# 74    0.054006
# 76   0.0543617
# 78    0.054699
# 80   0.0550196
# 82   0.0553244
# 84   0.0556148
# 86   0.0558916
# 88   0.0561559
# 90   0.0564084
# 92     0.05665
# 94   0.0568813
# 96   0.0571029
# 98   0.0573155
# 100  0.0575196
#
# [31 rows x 51 columns]

# %%
subFolder = "SG2-HSR/"
av_avg_delay.to_csv(subFolder+'av_avg_delay.csv')
av_max_delay.to_csv(subFolder+'av_max_delay.csv')
av_vdr.to_csv(subFolder+'av_vdr.csv')
cav_avg_delay.to_csv(subFolder+'cav_avg_delay.csv')
cav_max_delay.to_csv(subFolder+'cav_max_delay.csv')
cav_vdr.to_csv(subFolder+'cav_vdr.csv')
human_avg_delay.to_csv(subFolder+'human_avg_delay.csv')
human_max_delay.to_csv(subFolder+'human_max_delay.csv')
human_vdr.to_csv(subFolder+'human_vdr.csv')
